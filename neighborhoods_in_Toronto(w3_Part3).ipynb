# %% [markdown]
# <a href="https://colab.research.google.com/github/spdraptor/Coursera_Capstone/blob/main/neighborhoods_in_Toronto(w3_Part3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **IBM coursera neighborhoods in Toronto**

# %%
# Package Instalation
# !pip install beautifulsoup4
# !pip install geocoder
# !pip install tqdm
print('done')
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Requirement already satisfied: geocoder in /usr/local/lib/python3.7/dist-packages (1.38.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from geocoder) (1.15.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.7/dist-packages (from geocoder) (0.1.6)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from geocoder) (0.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.41.1)
# done

# %% [markdown]
#  **import all packages**

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import geocoder # import geocoder
from geopy.geocoders import Nominatim 
import numpy as np # library to handle data in a vectorized manner
import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
print('imported sucessfully')
# Out:
# imported sucessfully

# %% [markdown]
# **Parse the Wiki link to extract table data**

# %%
table_contents=[]
page=urlopen('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').read()
soup = BeautifulSoup(page)
table=soup.find('table')
for row in table.findAll('td'):
  cell = {}
  if row.span.text=='Not assigned':
      pass
  else:
      cell['PostalCode'] = row.p.text[:3]
      cell['Borough'] = (row.span.text).split('(')[0]
      cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
      table_contents.append(cell)

# %% [markdown]
# **Dispaly and check the data**

# %%
table_contents
# Out:
# [{'Borough': 'North York', 'Neighborhood': 'Parkwoods', 'PostalCode': 'M3A'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Victoria Village',
#   'PostalCode': 'M4A'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Regent Park, Harbourfront',
#   'PostalCode': 'M5A'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Lawrence Manor, Lawrence Heights',
#   'PostalCode': 'M6A'},
#  {'Borough': "Queen's Park",
#   'Neighborhood': 'Ontario Provincial Government',
#   'PostalCode': 'M7A'},
#  {'Borough': 'Etobicoke',
#   'Neighborhood': 'Islington Avenue',
#   'PostalCode': 'M9A'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': 'Malvern, Rouge',
#   'PostalCode': 'M1B'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Don Mills North',
#   'PostalCode': 'M3B'},
#  {'Borough': 'East York',
#   'Neighborhood': 'Parkview Hill, Woodbine Gardens',
#   'PostalCode': 'M4B'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Garden District, Ryerson',
#   'PostalCode': 'M5B'},
#  {'Borough': 'North York', 'Neighborhood': 'Glencairn', 'PostalCode': 'M6B'},
#  {'Borough': 'Etobicoke',
#   'Neighborhood': 'West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale',
#   'PostalCode': 'M9B'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': 'Rouge Hill, Port Union, Highland Creek',
#   'PostalCode': 'M1C'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Don Mills South',
#   'PostalCode': 'M3C'},
#  {'Borough': 'East York',
#   'Neighborhood': 'Woodbine Heights',
#   'PostalCode': 'M4C'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'St. James Town',
#   'PostalCode': 'M5C'},
#  {'Borough': 'York',
#   'Neighborhood': 'Humewood-Cedarvale',
#   'PostalCode': 'M6C'},
#  {'Borough': 'Etobicoke',
#   'Neighborhood': 'Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood',
#   'PostalCode': 'M9C'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': 'Guildwood, Morningside, West Hill',
#   'PostalCode': 'M1E'},
#  {'Borough': 'East Toronto',
#   'Neighborhood': 'The Beaches',
#   'PostalCode': 'M4E'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Berczy Park',
#   'PostalCode': 'M5E'},
#  {'Borough': 'York',
#   'Neighborhood': 'Caledonia-Fairbanks',
#   'PostalCode': 'M6E'},
#  {'Borough': 'Scarborough', 'Neighborhood': 'Woburn', 'PostalCode': 'M1G'},
#  {'Borough': 'East York', 'Neighborhood': 'Leaside', 'PostalCode': 'M4G'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Central Bay Street',
#   'PostalCode': 'M5G'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Christie',
#   'PostalCode': 'M6G'},
#  {'Borough': 'Scarborough', 'Neighborhood': 'Cedarbrae', 'PostalCode': 'M1H'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Hillcrest Village',
#   'PostalCode': 'M2H'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Bathurst Manor, Wilson Heights, Downsview North',
#   'PostalCode': 'M3H'},
#  {'Borough': 'East York',
#   'Neighborhood': 'Thorncliffe Park',
#   'PostalCode': 'M4H'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Richmond, Adelaide, King',
#   'PostalCode': 'M5H'},
#  {'Borough': 'West Toronto',
#   'Neighborhood': 'Dufferin, Dovercourt Village',
#   'PostalCode': 'M6H'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': 'Scarborough Village',
#   'PostalCode': 'M1J'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Fairview, Henry Farm, Oriole',
#   'PostalCode': 'M2J'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Northwood Park, York University',
#   'PostalCode': 'M3J'},
#  {'Borough': 'East YorkEast Toronto',
#   'Neighborhood': 'The Danforth  East',
#   'PostalCode': 'M4J'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Harbourfront East, Union Station, Toronto Islands',
#   'PostalCode': 'M5J'},
#  {'Borough': 'West Toronto',
#   'Neighborhood': 'Little Portugal, Trinity',
#   'PostalCode': 'M6J'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': 'Kennedy Park, Ionview, East Birchmount Park',
#   'PostalCode': 'M1K'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Bayview Village',
#   'PostalCode': 'M2K'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Downsview East',
#   'PostalCode': 'M3K'},
#  {'Borough': 'East Toronto',
#   'Neighborhood': 'The Danforth West, Riverdale',
#   'PostalCode': 'M4K'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Toronto Dominion Centre, Design Exchange',
#   'PostalCode': 'M5K'},
#  {'Borough': 'West Toronto',
#   'Neighborhood': 'Brockton, Parkdale Village, Exhibition Place',
#   'PostalCode': 'M6K'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': 'Golden Mile, Clairlea, Oakridge',
#   'PostalCode': 'M1L'},
#  {'Borough': 'North York',
#   'Neighborhood': 'York Mills, Silver Hills',
#   'PostalCode': 'M2L'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Downsview West',
#   'PostalCode': 'M3L'},
#  {'Borough': 'East Toronto',
#   'Neighborhood': 'India Bazaar, The Beaches West',
#   'PostalCode': 'M4L'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Commerce Court, Victoria Hotel',
#   'PostalCode': 'M5L'},
#  {'Borough': 'North York',
#   'Neighborhood': 'North Park, Maple Leaf Park, Upwood Park',
#   'PostalCode': 'M6L'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Humber Summit',
#   'PostalCode': 'M9L'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': 'Cliffside, Cliffcrest, Scarborough Village West',
#   'PostalCode': 'M1M'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Willowdale, Newtonbrook',
#   'PostalCode': 'M2M'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Downsview Central',
#   'PostalCode': 'M3M'},
#  {'Borough': 'East Toronto',
#   'Neighborhood': 'Studio District',
#   'PostalCode': 'M4M'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Bedford Park, Lawrence Manor East',
#   'PostalCode': 'M5M'},
#  {'Borough': 'York',
#   'Neighborhood': 'Del Ray, Mount Dennis, Keelsdale and Silverthorn',
#   'PostalCode': 'M6M'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Humberlea, Emery',
#   'PostalCode': 'M9M'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': 'Birch Cliff, Cliffside West',
#   'PostalCode': 'M1N'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Willowdale South',
#   'PostalCode': 'M2N'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Downsview Northwest',
#   'PostalCode': 'M3N'},
#  {'Borough': 'Central Toronto',
#   'Neighborhood': 'Lawrence Park',
#   'PostalCode': 'M4N'},
#  {'Borough': 'Central Toronto',
#   'Neighborhood': 'Roselawn',
#   'PostalCode': 'M5N'},
#  {'Borough': 'York',
#   'Neighborhood': 'Runnymede, The Junction North',
#   'PostalCode': 'M6N'},
#  {'Borough': 'York', 'Neighborhood': 'Weston', 'PostalCode': 'M9N'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': 'Dorset Park, Wexford Heights, Scarborough Town Centre',
#   'PostalCode': 'M1P'},
#  {'Borough': 'North York',
#   'Neighborhood': 'York Mills West',
#   'PostalCode': 'M2P'},
#  {'Borough': 'Central Toronto',
#   'Neighborhood': 'Davisville North',
#   'PostalCode': 'M4P'},
#  {'Borough': 'Central Toronto',
#   'Neighborhood': 'Forest Hill North & West',
#   'PostalCode': 'M5P'},
#  {'Borough': 'West Toronto',
#   'Neighborhood': 'High Park, The Junction South',
#   'PostalCode': 'M6P'},
#  {'Borough': 'Etobicoke', 'Neighborhood': 'Westmount', 'PostalCode': 'M9P'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': 'Wexford, Maryvale',
#   'PostalCode': 'M1R'},
#  {'Borough': 'North York',
#   'Neighborhood': 'Willowdale West',
#   'PostalCode': 'M2R'},
#  {'Borough': 'Central Toronto',
#   'Neighborhood': 'North Toronto West',
#   'PostalCode': 'M4R'},
#  {'Borough': 'Central Toronto',
#   'Neighborhood': 'The Annex, North Midtown, Yorkville',
#   'PostalCode': 'M5R'},
#  {'Borough': 'West Toronto',
#   'Neighborhood': 'Parkdale, Roncesvalles',
#   'PostalCode': 'M6R'},
#  {'Borough': 'MississaugaCanada Post Gateway Processing Centre',
#   'Neighborhood': 'Enclave of L4W',
#   'PostalCode': 'M7R'},
#  {'Borough': 'Etobicoke',
#   'Neighborhood': 'Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens',
#   'PostalCode': 'M9R'},
#  {'Borough': 'Scarborough', 'Neighborhood': 'Agincourt', 'PostalCode': 'M1S'},
#  {'Borough': 'Central Toronto',
#   'Neighborhood': 'Davisville',
#   'PostalCode': 'M4S'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'University of Toronto, Harbord',
#   'PostalCode': 'M5S'},
#  {'Borough': 'West Toronto',
#   'Neighborhood': 'Runnymede, Swansea',
#   'PostalCode': 'M6S'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': "Clarks Corners, Tam O'Shanter, Sullivan",
#   'PostalCode': 'M1T'},
#  {'Borough': 'Central Toronto',
#   'Neighborhood': 'Moore Park, Summerhill East',
#   'PostalCode': 'M4T'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Kensington Market, Chinatown, Grange Park',
#   'PostalCode': 'M5T'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': "Milliken, Agincourt North, Steeles East, L'Amoreaux East",
#   'PostalCode': 'M1V'},
#  {'Borough': 'Central Toronto',
#   'Neighborhood': 'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#   'PostalCode': 'M4V'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport',
#   'PostalCode': 'M5V'},
#  {'Borough': 'Etobicoke',
#   'Neighborhood': 'New Toronto, Mimico South, Humber Bay Shores',
#   'PostalCode': 'M8V'},
#  {'Borough': 'Etobicoke',
#   'Neighborhood': 'South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens',
#   'PostalCode': 'M9V'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': "Steeles West, L'Amoreaux West",
#   'PostalCode': 'M1W'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Rosedale',
#   'PostalCode': 'M4W'},
#  {'Borough': 'Downtown TorontoStn A PO Boxes25 The Esplanade',
#   'Neighborhood': 'Enclave of M5E',
#   'PostalCode': 'M5W'},
#  {'Borough': 'Etobicoke',
#   'Neighborhood': 'Alderwood, Long Branch',
#   'PostalCode': 'M8W'},
#  {'Borough': 'EtobicokeNorthwest',
#   'Neighborhood': 'Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale',
#   'PostalCode': 'M9W'},
#  {'Borough': 'Scarborough',
#   'Neighborhood': 'Upper Rouge',
#   'PostalCode': 'M1X'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'St. James Town, Cabbagetown',
#   'PostalCode': 'M4X'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'First Canadian Place, Underground city',
#   'PostalCode': 'M5X'},
#  {'Borough': 'Etobicoke',
#   'Neighborhood': 'The Kingsway, Montgomery Road, Old Mill North',
#   'PostalCode': 'M8X'},
#  {'Borough': 'Downtown Toronto',
#   'Neighborhood': 'Church and Wellesley',
#   'PostalCode': 'M4Y'},
#  {'Borough': 'East TorontoBusiness reply mail Processing Centre969 Eastern',
#   'Neighborhood': 'Enclave of M4L',
#   'PostalCode': 'M7Y'},
#  {'Borough': 'Etobicoke',
#   'Neighborhood': "Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East",
#   'PostalCode': 'M8Y'},
#  {'Borough': 'Etobicoke',
#   'Neighborhood': 'Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West',
#   'PostalCode': 'M8Z'}]

# %% [markdown]
# **Convert the extracted data in DataFrame**

# %%
df=pd.DataFrame(table_contents)
df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})
df
# Out:
#     PostalCode  ...                                       Neighborhood
# 0          M3A  ...                                          Parkwoods
# 1          M4A  ...                                   Victoria Village
# 2          M5A  ...                          Regent Park, Harbourfront
# 3          M6A  ...                   Lawrence Manor, Lawrence Heights
# 4          M7A  ...                      Ontario Provincial Government
# ..         ...  ...                                                ...
# 98         M8X  ...      The Kingsway, Montgomery Road, Old Mill North
# 99         M4Y  ...                               Church and Wellesley
# 100        M7Y  ...                                     Enclave of M4L
# 101        M8Y  ...  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102        M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %% [markdown]
# **Find the shape or the data size**

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ***geocoder.google wasn't returning anything so I used geocoder.arcgis to get coordinate***

# %% [markdown]
# defined function to get coordinate

# %%
def coordinate(postal_code):
  # initialize your variable to None
  lat_lng_coords = None

  # loop until you get the coordinates
  while(lat_lng_coords is None):
    g = geocoder.arcgis('{}, Toronto, Ontario'.format(postal_code))
    lat_lng_coords = g.latlng
  return lat_lng_coords  #returns in format[latitude, longitude]

# %%
coordinate('M5G')
# Out:
# [43.65609000000006, -79.38492999999994]

# %% [markdown]
# **use coordinate function to get latitude and logitude**

# %%
from tqdm import tqdm
temp_df = pd.DataFrame()
pc=[]
lat=[]
long=[]
for i in tqdm(df['PostalCode']):
  a=coordinate(i)
  pc.append(i)
  lat.append(a[0])
  long.append(a[1])

temp_df['PostalCode']=pc
temp_df['latitude']=lat
temp_df['longitude']=long
print('done')
# Out:
# 100%|██████████| 103/103 [01:00<00:00,  1.70it/s]
# done

# %%
temp_df
# Out:
#     PostalCode  latitude  longitude
# 0          M3A  43.75245  -79.32991
# 1          M4A  43.73057  -79.31306
# 2          M5A  43.65512  -79.36264
# 3          M6A  43.72327  -79.45042
# 4          M7A  43.66253  -79.39188
# ..         ...       ...        ...
# 98         M8X  43.65319  -79.51113
# 99         M4Y  43.66659  -79.38133
# 100        M7Y  43.64869  -79.38544
# 101        M8Y  43.63278  -79.48945
# 102        M8Z  43.62513  -79.52681
#
# [103 rows x 3 columns]

# %% [markdown]
# **add latitude and longitude to dataframe**

# %%
df2 = df.merge(temp_df, on="PostalCode", how="left")
df2.head()
# Out:
#   PostalCode           Borough  ...  latitude  longitude
# 0        M3A        North York  ...  43.75245  -79.32991
# 1        M4A        North York  ...  43.73057  -79.31306
# 2        M5A  Downtown Toronto  ...  43.65512  -79.36264
# 3        M6A        North York  ...  43.72327  -79.45042
# 4        M7A      Queen's Park  ...  43.66253  -79.39188
#
# [5 rows x 5 columns]

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df2['latitude'], df2['longitude'], df2['Borough'], df2['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='cyan',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_c0d3360a42564df6ba12538cd032b11a%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c0d3360a42564df6ba12538cd032b11a%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_c0d3360a42564df6ba12538cd032b11a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_c0d3360a42564df6ba12538cd032b11a%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_a8e6054bf0f34f42a871e6272e60df43%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# *My foursquare credentials*

# %%
CLIENT_ID = 'ADEVMXXEO1Z52RYHRM2QNY0CILIAFLPDA1TS5H2RKPBQKLQD' # your Foursquare ID
CLIENT_SECRET = 'VQ4MMGRGASRIE3JPYDZPTDK1GFG0CQFYCV20KFSIVUA4OFYC' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ADEVMXXEO1Z52RYHRM2QNY0CILIAFLPDA1TS5H2RKPBQKLQD
# CLIENT_SECRET:VQ4MMGRGASRIE3JPYDZPTDK1GFG0CQFYCV20KFSIVUA4OFYC

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
venues_in_toronto = getNearbyVenues(df2['Neighborhood'], df2['latitude'], df2['longitude'])
# Out:
# Parkwoods
# Victoria Village
# Regent Park, Harbourfront
# Lawrence Manor, Lawrence Heights
# Ontario Provincial Government
# Islington Avenue
# Malvern, Rouge
# Don Mills North
# Parkview Hill, Woodbine Gardens
# Garden District, Ryerson
# Glencairn
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Rouge Hill, Port Union, Highland Creek
# Don Mills South
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor, Wilson Heights, Downsview North
# Thorncliffe Park
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Scarborough Village
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# The Danforth  East
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# Kennedy Park, Ionview, East Birchmount Park
# Bayview Village
# Downsview East
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# Golden Mile, Clairlea, Oakridge
# York Mills, Silver Hills
# Downsview West
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# North Park, Maple Leaf Park, Upwood Park
# Humber Summit
# Cliffside, Cliffcrest, Scarborough Village West
# Willowdale, Newtonbrook
# Downsview Central
# Studio District
# Bedford Park, Lawrence Manor East
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Humberlea, Emery
# Birch Cliff, Cliffside West
# Willowdale South
# Downsview Northwest
# Lawrence Park
# Roselawn
# Runnymede, The Junction North
# Weston
# Dorset Park, Wexford Heights, Scarborough Town Centre
# York Mills West
# Davisville North
# Forest Hill North & West
# High Park, The Junction South
# Westmount
# Wexford, Maryvale
# Willowdale West
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Enclave of L4W
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# Agincourt
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Clarks Corners, Tam O'Shanter, Sullivan
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# New Toronto, Mimico South, Humber Bay Shores
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Steeles West, L'Amoreaux West
# Rosedale
# Enclave of M5E
# Alderwood, Long Branch
# Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale
# Upper Rouge
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# The Kingsway, Montgomery Road, Old Mill North
# Church and Wellesley
# Enclave of M4L
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West

# %%
venues_in_toronto.head()
# Out:
#        Neighborhood  ...        Venue Category
# 0         Parkwoods  ...                  Park
# 1         Parkwoods  ...  Fast Food Restaurant
# 2         Parkwoods  ...     Food & Drink Shop
# 3  Victoria Village  ...                  Park
# 4  Victoria Village  ...         Grocery Store
#
# [5 rows x 7 columns]

# %%
venues_in_toronto.groupby('Neighborhood').count()
# Out:
#                                                  Neighborhood Latitude  ...  Venue Category
# Neighborhood                                                            ...
# Agincourt                                                           15  ...              15
# Alderwood, Long Branch                                               4  ...               4
# Bathurst Manor, Wilson Heights, Downsview North                      2  ...               2
# Bayview Village                                                      5  ...               5
# Bedford Park, Lawrence Manor East                                   23  ...              23
# ...                                                                ...  ...             ...
# Willowdale, Newtonbrook                                             22  ...              22
# Woburn                                                               4  ...               4
# Woodbine Heights                                                    19  ...              19
# York Mills West                                                      4  ...               4
# York Mills, Silver Hills                                             1  ...               1
#
# [102 rows x 6 columns]

# %%
print('There are {} uniques categories.'.format(len(venues_in_toronto['Venue Category'].unique())))
# Out:
# There are 267 uniques categories.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(venues_in_toronto[['Venue Category']], prefix="", prefix_sep="")

# %%
# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = venues_in_toronto['Neighborhood']

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# %%
toronto_onehot.head()
# Out:
#       Neighbourhood  Accessories Store  ...  Women's Store  Yoga Studio
# 0         Parkwoods                  0  ...              0            0
# 1         Parkwoods                  0  ...              0            0
# 2         Parkwoods                  0  ...              0            0
# 3  Victoria Village                  0  ...              0            0
# 4  Victoria Village                  0  ...              0            0
#
# [5 rows x 268 columns]

# %%
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped.head()
# Out:
#                                      Neighbourhood  ...  Yoga Studio
# 0                                        Agincourt  ...          0.0
# 1                           Alderwood, Long Branch  ...          0.0
# 2  Bathurst Manor, Wilson Heights, Downsview North  ...          0.0
# 3                                  Bayview Village  ...          0.0
# 4                Bedford Park, Lawrence Manor East  ...          0.0
#
# [5 rows x 268 columns]

# %%
toronto_onehot.shape
# Out:
# (2379, 268)

# %%
num_top_venues=5

for hood in toronto_grouped['Neighbourhood']:
  print("-------"+hood+"-------")
  temp=toronto_grouped[toronto_grouped['Neighbourhood']==hood].T.reset_index()
  temp.columns = ['venue','freq']
  temp = temp.iloc[1:]
  temp['freq'] = temp['freq'].astype(float)
  temp = temp.round({'freq': 2})
  print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
  print('\n')
# Out:
# -------Agincourt-------
#                 venue  freq
# 0  Chinese Restaurant  0.13
# 1       Shopping Mall  0.07
# 2        Skating Rink  0.07
# 3    Sushi Restaurant  0.07
# 4              Bakery  0.07
#
#
# -------Alderwood, Long Branch-------
#                venue  freq
# 0  Convenience Store  0.25
# 1                Gym  0.25
# 2       Dance Studio  0.25
# 3                Pub  0.25
# 4          Newsagent  0.00
#
#
# -------Bathurst Manor, Wilson Heights, Downsview North-------
#                      venue  freq
# 0         Business Service   0.5
# 1                   Lawyer   0.5
# 2        Accessories Store   0.0
# 3  New American Restaurant   0.0
# 4             Neighborhood   0.0
#
#
# -------Bayview Village-------
#                         venue  freq
# 0                       Trail   0.4
# 1                        Park   0.2
# 2  Construction & Landscaping   0.2
# 3                     Dog Run   0.2
# 4           Accessories Store   0.0
#
#
# -------Bedford Park, Lawrence Manor East-------
#                 venue  freq
# 0         Coffee Shop  0.09
# 1  Italian Restaurant  0.09
# 2      Sandwich Place  0.09
# 3                 Spa  0.04
# 4     Thai Restaurant  0.04
#
#
# -------Berczy Park-------
#                 venue  freq
# 0         Coffee Shop  0.10
# 1        Cocktail Bar  0.06
# 2              Bakery  0.05
# 3  Seafood Restaurant  0.05
# 4      Breakfast Spot  0.03
#
#
# -------Birch Cliff, Cliffside West-------
#                    venue  freq
# 0  General Entertainment  0.25
# 1           Skating Rink  0.25
# 2                   Café  0.25
# 3        College Stadium  0.25
# 4              Newsagent  0.00
#
#
# -------Brockton, Parkdale Village, Exhibition Place-------
#          venue  freq
# 0          Bar  0.07
# 1         Café  0.06
# 2  Coffee Shop  0.05
# 3   Restaurant  0.05
# 4    Gift Shop  0.04
#
#
# -------CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport-------
#                 venue  freq
# 0  Italian Restaurant  0.08
# 1         Coffee Shop  0.07
# 2                Café  0.05
# 3                 Bar  0.04
# 4   French Restaurant  0.04
#
#
# -------Caledonia-Fairbanks-------
#                 venue  freq
# 0              Bakery  0.14
# 1                Park  0.14
# 2  Mexican Restaurant  0.14
# 3                Café  0.14
# 4          Beer Store  0.14
#
#
# -------Cedarbrae-------
#                venue  freq
# 0        Gaming Cafe  0.33
# 1              Trail  0.33
# 2             Lounge  0.33
# 3  Accessories Store  0.00
# 4       Neighborhood  0.00
#
#
# -------Central Bay Street-------
#             venue  freq
# 0     Coffee Shop  0.12
# 1  Clothing Store  0.07
# 2           Plaza  0.03
# 3     Pizza Place  0.03
# 4            Café  0.03
#
#
# -------Christie-------
#                 venue  freq
# 0                Café  0.27
# 1       Grocery Store  0.18
# 2  Athletics & Sports  0.09
# 3         Candy Store  0.09
# 4          Playground  0.09
#
#
# -------Church and Wellesley-------
#                  venue  freq
# 0          Coffee Shop  0.11
# 1  Japanese Restaurant  0.06
# 2           Restaurant  0.05
# 3     Sushi Restaurant  0.05
# 4              Gay Bar  0.04
#
#
# -------Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale-------
#                        venue  freq
# 0                        Gym  0.12
# 1           Storage Facility  0.12
# 2                Gas Station  0.12
# 3  Middle Eastern Restaurant  0.12
# 4                 Restaurant  0.12
#
#
# -------Clarks Corners, Tam O'Shanter, Sullivan-------
#                   venue  freq
# 0  Fast Food Restaurant  0.13
# 1                  Bank  0.07
# 2      Video Game Store  0.07
# 3           Coffee Shop  0.07
# 4           Golf Course  0.07
#
#
# -------Cliffside, Cliffcrest, Scarborough Village West-------
#             venue  freq
# 0  Ice Cream Shop  0.22
# 1     Pizza Place  0.11
# 2  Sandwich Place  0.11
# 3    Liquor Store  0.11
# 4      Restaurant  0.11
#
#
# -------Commerce Court, Victoria Hotel-------
#                 venue  freq
# 0         Coffee Shop  0.14
# 1          Restaurant  0.07
# 2               Hotel  0.06
# 3  Italian Restaurant  0.05
# 4                Café  0.05
#
#
# -------Davisville-------
#                 venue  freq
# 0        Dessert Shop  0.12
# 1         Pizza Place  0.08
# 2  Italian Restaurant  0.08
# 3         Coffee Shop  0.08
# 4      Sandwich Place  0.08
#
#
# -------Davisville North-------
#                venue  freq
# 0              Hotel  0.29
# 1  Food & Drink Shop  0.14
# 2   Department Store  0.14
# 3     Breakfast Spot  0.14
# 4               Park  0.14
#
#
# -------Del Ray, Mount Dennis, Keelsdale and Silverthorn-------
#                   venue  freq
# 0            Playground  0.25
# 1          Intersection  0.25
# 2  Fast Food Restaurant  0.25
# 3           Coffee Shop  0.25
# 4         Moving Target  0.00
#
#
# -------Don Mills North-------
#            venue  freq
# 0           Park  0.25
# 1   Burger Joint  0.25
# 2    Gas Station  0.25
# 3    Coffee Shop  0.25
# 4  Moving Target  0.00
#
#
# -------Don Mills South-------
#              venue  freq
# 0  Bubble Tea Shop  0.14
# 1     Intersection  0.14
# 2      Coffee Shop  0.14
# 3      Supermarket  0.14
# 4    Grocery Store  0.14
#
#
# -------Dorset Park, Wexford Heights, Scarborough Town Centre-------
#                 venue  freq
# 0              Bakery  0.33
# 1           Gift Shop  0.33
# 2  Light Rail Station  0.33
# 3   Accessories Store  0.00
# 4           Newsagent  0.00
#
#
# -------Downsview Central-------
#                         venue  freq
# 0  Construction & Landscaping   1.0
# 1                Noodle House   0.0
# 2          Miscellaneous Shop   0.0
# 3           Mobile Phone Shop   0.0
# 4  Modern European Restaurant   0.0
#
#
# -------Downsview East-------
#                 venue  freq
# 0  Turkish Restaurant   0.2
# 1                Park   0.1
# 2  Chinese Restaurant   0.1
# 3      Sandwich Place   0.1
# 4  Italian Restaurant   0.1
#
#
# -------Downsview Northwest-------
#             venue  freq
# 0     Pizza Place  0.11
# 1  Discount Store  0.11
# 2   Shopping Mall  0.11
# 3   Grocery Store  0.11
# 4        Pharmacy  0.05
#
#
# -------Downsview West-------
#                   venue  freq
# 0          Hockey Arena  0.09
# 1        Discount Store  0.09
# 2           Pizza Place  0.09
# 3  Fast Food Restaurant  0.09
# 4            Beer Store  0.09
#
#
# -------Dufferin, Dovercourt Village-------
#                     venue  freq
# 0  Furniture / Home Store  0.10
# 1                    Park  0.10
# 2                     Bar  0.05
# 3                    Bank  0.05
# 4                  Bakery  0.05
#
#
# -------Enclave of L4W-------
#               venue  freq
# 0       Coffee Shop  0.07
# 1             Hotel  0.05
# 2              Café  0.04
# 3  Asian Restaurant  0.03
# 4      Concert Hall  0.02
#
#
# -------Enclave of M4L-------
#               venue  freq
# 0       Coffee Shop  0.07
# 1             Hotel  0.05
# 2              Café  0.04
# 3  Asian Restaurant  0.03
# 4      Concert Hall  0.02
#
#
# -------Enclave of M5E-------
#               venue  freq
# 0       Coffee Shop  0.07
# 1             Hotel  0.05
# 2              Café  0.04
# 3  Asian Restaurant  0.03
# 4      Concert Hall  0.02
#
#
# -------Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood-------
#                 venue  freq
# 0                Park  0.17
# 1  College Rec Center  0.17
# 2       Shopping Mall  0.17
# 3       Grocery Store  0.17
# 4   Electronics Store  0.17
#
#
# -------Fairview, Henry Farm, Oriole-------
#                   venue  freq
# 0        Clothing Store  0.15
# 1        Cosmetics Shop  0.06
# 2  Fast Food Restaurant  0.06
# 3            Restaurant  0.06
# 4           Coffee Shop  0.06
#
#
# -------First Canadian Place, Underground city-------
#                  venue  freq
# 0          Coffee Shop  0.14
# 1                Hotel  0.07
# 2                 Café  0.06
# 3  Japanese Restaurant  0.04
# 4                  Gym  0.04
#
#
# -------Forest Hill North & West-------
#                      venue  freq
# 0                     Park   1.0
# 1        Accessories Store   0.0
# 2  New American Restaurant   0.0
# 3             Neighborhood   0.0
# 4              Music Venue   0.0
#
#
# -------Garden District, Ryerson-------
#                  venue  freq
# 0          Coffee Shop  0.10
# 1       Clothing Store  0.06
# 2                 Café  0.04
# 3  Japanese Restaurant  0.03
# 4   Italian Restaurant  0.03
#
#
# -------Glencairn-------
#                       venue  freq
# 0               Pizza Place  0.17
# 1             Grocery Store  0.17
# 2       Japanese Restaurant  0.08
# 3  Mediterranean Restaurant  0.08
# 4      Fast Food Restaurant  0.08
#
#
# -------Golden Mile, Clairlea, Oakridge-------
#            venue  freq
# 0         Bakery  0.22
# 1   Intersection  0.22
# 2    Coffee Shop  0.22
# 3  Metro Station  0.11
# 4   Soccer Field  0.11
#
#
# -------Guildwood, Morningside, West Hill-------
#                         venue  freq
# 0                        Park  0.25
# 1  Construction & Landscaping  0.25
# 2        Gym / Fitness Center  0.25
# 3                    Tea Room  0.25
# 4           Accessories Store  0.00
#
#
# -------Harbourfront East, Union Station, Toronto Islands-------
#                  venue  freq
# 0          Coffee Shop  0.13
# 1                Hotel  0.08
# 2                 Park  0.06
# 3  Japanese Restaurant  0.06
# 4        Boat or Ferry  0.04
#
#
# -------High Park, The Junction South-------
#                      venue  freq
# 0           Sandwich Place   0.5
# 1                     Park   0.5
# 2                Newsagent   0.0
# 3  New American Restaurant   0.0
# 4             Neighborhood   0.0
#
#
# -------Hillcrest Village-------
#                                       venue  freq
# 0                                      Park   0.5
# 1  Residential Building (Apartment / Condo)   0.5
# 2                         Accessories Store   0.0
# 3                   New American Restaurant   0.0
# 4                              Neighborhood   0.0
#
#
# -------Humber Summit-------
#                         venue  freq
# 0  Construction & Landscaping  0.33
# 1                Home Service  0.17
# 2      Furniture / Home Store  0.17
# 3                  Print Shop  0.17
# 4         Rental Car Location  0.17
#
#
# -------Humberlea, Emery-------
#                      venue  freq
# 0              Coffee Shop  0.50
# 1                     Park  0.25
# 2                Nightclub  0.25
# 3        Accessories Store  0.00
# 4  New American Restaurant  0.00
#
#
# -------Humewood-Cedarvale-------
#           venue  freq
# 0  Hockey Arena  0.14
# 1         Trail  0.14
# 2    Playground  0.14
# 3       Dog Run  0.14
# 4          Park  0.14
#
#
# -------India Bazaar, The Beaches West-------
#                   venue  freq
# 0  Fast Food Restaurant  0.11
# 1                  Park  0.11
# 2          Liquor Store  0.06
# 3      Sushi Restaurant  0.06
# 4        Sandwich Place  0.06
#
#
# -------Islington Avenue-------
#            venue  freq
# 0       Pharmacy  0.25
# 1  Grocery Store  0.12
# 2  Shopping Mall  0.12
# 3   Skating Rink  0.12
# 4           Park  0.12
#
#
# -------Kennedy Park, Ionview, East Birchmount Park-------
#                venue  freq
# 0  Convenience Store   0.2
# 1         Hobby Shop   0.2
# 2   Department Store   0.2
# 3        Coffee Shop   0.2
# 4     Discount Store   0.2
#
#
# -------Kensington Market, Chinatown, Grange Park-------
#                      venue  freq
# 0                     Café  0.08
# 1              Coffee Shop  0.06
# 2  Comfort Food Restaurant  0.04
# 3      Arts & Crafts Store  0.04
# 4             Burger Joint  0.04
#
#
# -------Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens-------
#                  venue  freq
# 0          Pizza Place  0.25
# 1             Bus Line  0.25
# 2  Arts & Crafts Store  0.25
# 3        Jewelry Store  0.25
# 4    Accessories Store  0.00
#
#
# -------Lawrence Manor, Lawrence Heights-------
#             venue  freq
# 0  Clothing Store  0.22
# 1   Women's Store  0.04
# 2      Restaurant  0.04
# 3     Men's Store  0.04
# 4  Cosmetics Shop  0.04
#
#
# -------Lawrence Park-------
#                      venue  freq
# 0                 Bus Line   0.5
# 1              Swim School   0.5
# 2        Accessories Store   0.0
# 3            Movie Theater   0.0
# 4  New American Restaurant   0.0
#
#
# -------Leaside-------
#                  venue  freq
# 0          Coffee Shop  0.13
# 1  Sporting Goods Shop  0.10
# 2         Burger Joint  0.06
# 3                 Bank  0.06
# 4           Sports Bar  0.03
#
#
# -------Little Portugal, Trinity-------
#                    venue  freq
# 0           Cocktail Bar  0.07
# 1            Coffee Shop  0.07
# 2                    Bar  0.07
# 3             Restaurant  0.05
# 4  Vietnamese Restaurant  0.05
#
#
# -------Malvern, Rouge-------
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1     Accessories Store   0.0
# 2             Nightclub   0.0
# 3    Miscellaneous Shop   0.0
# 4     Mobile Phone Shop   0.0
#
#
# -------Milliken, Agincourt North, Steeles East, L'Amoreaux East-------
#                      venue  freq
# 0             Intersection   0.5
# 1                 Pharmacy   0.5
# 2      Moroccan Restaurant   0.0
# 3  New American Restaurant   0.0
# 4             Neighborhood   0.0
#
#
# -------Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West-------
#                   venue  freq
# 0                  Bank  0.08
# 1  Gym / Fitness Center  0.08
# 2    Miscellaneous Shop  0.08
# 3     Food & Drink Shop  0.08
# 4        Mattress Store  0.08
#
#
# -------Moore Park, Summerhill East-------
#                      venue  freq
# 0                      Gym  0.67
# 1                    Trail  0.33
# 2                Nightclub  0.00
# 3  New American Restaurant  0.00
# 4             Neighborhood  0.00
#
#
# -------New Toronto, Mimico South, Humber Bay Shores-------
#            venue  freq
# 0           Park  0.29
# 1    Yoga Studio  0.14
# 2   Tennis Court  0.14
# 3  Grocery Store  0.14
# 4   Skating Rink  0.14
#
#
# -------North Park, Maple Leaf Park, Upwood Park-------
#                venue  freq
# 0             Bakery  0.33
# 1   Basketball Court  0.33
# 2               Park  0.33
# 3  Accessories Store  0.00
# 4          Newsagent  0.00
#
#
# -------North Toronto West-------
#                      venue  freq
# 0               Playground  0.33
# 1                     Park  0.33
# 2                 Gym Pool  0.33
# 3  New American Restaurant  0.00
# 4             Neighborhood  0.00
#
#
# -------Northwood Park, York University-------
#                     venue  freq
# 0  Furniture / Home Store  0.15
# 1             Frame Store  0.08
# 2         Automotive Shop  0.08
# 3           Metro Station  0.08
# 4          Massage Studio  0.08
#
#
# -------Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East-------
#                 venue  freq
# 0                Park  0.12
# 1  Italian Restaurant  0.12
# 2  Chinese Restaurant  0.12
# 3         Coffee Shop  0.12
# 4    Sushi Restaurant  0.12
#
#
# -------Ontario Provincial Government-------
#                       venue  freq
# 0               Coffee Shop  0.25
# 1                      Bank  0.06
# 2       Fried Chicken Joint  0.06
# 3  Mediterranean Restaurant  0.06
# 4                      Café  0.06
#
#
# -------Parkdale, Roncesvalles-------
#                          venue  freq
# 0                  Coffee Shop  0.07
# 1  Eastern European Restaurant  0.06
# 2             Sushi Restaurant  0.06
# 3            Food & Drink Shop  0.06
# 4              Thai Restaurant  0.06
#
#
# -------Parkview Hill, Woodbine Gardens-------
#                   venue  freq
# 0           Pizza Place  0.14
# 1  Gym / Fitness Center  0.07
# 2              Pharmacy  0.07
# 3             Pet Store  0.07
# 4    Rock Climbing Spot  0.07
#
#
# -------Parkwoods-------
#                      venue  freq
# 0        Food & Drink Shop  0.33
# 1                     Park  0.33
# 2     Fast Food Restaurant  0.33
# 3  New American Restaurant  0.00
# 4             Neighborhood  0.00
#
#
# -------Regent Park, Harbourfront-------
#             venue  freq
# 0     Coffee Shop  0.24
# 1  Breakfast Spot  0.10
# 2     Yoga Studio  0.05
# 3             Pub  0.05
# 4             Spa  0.05
#
#
# -------Richmond, Adelaide, King-------
#          venue  freq
# 0        Hotel  0.07
# 1         Café  0.06
# 2  Coffee Shop  0.06
# 3   Restaurant  0.05
# 4          Gym  0.04
#
#
# -------Rosedale-------
#           venue  freq
# 0          Park  0.50
# 1    Playground  0.25
# 2    Bike Trail  0.25
# 3  Neighborhood  0.00
# 4   Music Venue  0.00
#
#
# -------Roselawn-------
#                         venue  freq
# 0                Home Service   1.0
# 1                Noodle House   0.0
# 2          Miscellaneous Shop   0.0
# 3           Mobile Phone Shop   0.0
# 4  Modern European Restaurant   0.0
#
#
# -------Rouge Hill, Port Union, Highland Creek-------
#                      venue  freq
# 0                      Bar   1.0
# 1        Accessories Store   0.0
# 2            Movie Theater   0.0
# 3  New American Restaurant   0.0
# 4             Neighborhood   0.0
#
#
# -------Runnymede, Swansea-------
#          venue  freq
# 0  Coffee Shop  0.11
# 1         Café  0.11
# 2       Bakery  0.08
# 3  Pizza Place  0.05
# 4         Bank  0.05
#
#
# -------Runnymede, The Junction North-------
#                         venue  freq
# 0                     Brewery  0.25
# 1      Furniture / Home Store  0.25
# 2  Construction & Landscaping  0.25
# 3          Seafood Restaurant  0.25
# 4     New American Restaurant  0.00
#
#
# -------Scarborough Village-------
#                venue  freq
# 0                Spa   0.2
# 1  Indian Restaurant   0.2
# 2         Restaurant   0.2
# 3      Grocery Store   0.2
# 4               Park   0.2
#
#
# -------South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens-------
#                   venue  freq
# 0         Grocery Store  0.12
# 1           Auto Garage  0.06
# 2   Fried Chicken Joint  0.06
# 3            Beer Store  0.06
# 4  Caribbean Restaurant  0.06
#
#
# -------St. James Town-------
#                 venue  freq
# 0         Coffee Shop  0.06
# 1        Cocktail Bar  0.05
# 2          Restaurant  0.04
# 3  Italian Restaurant  0.04
# 4      Cosmetics Shop  0.04
#
#
# -------St. James Town, Cabbagetown-------
#                 venue  freq
# 0         Pizza Place  0.09
# 1         Coffee Shop  0.06
# 2                Café  0.06
# 3  Chinese Restaurant  0.04
# 4          Restaurant  0.04
#
#
# -------Steeles West, L'Amoreaux West-------
#                   venue  freq
# 0  Fast Food Restaurant  0.15
# 1           Pizza Place  0.08
# 2  Other Great Outdoors  0.08
# 3          Camera Store  0.08
# 4           Supermarket  0.08
#
#
# -------Studio District-------
#                  venue  freq
# 0                Diner  0.06
# 1          Pizza Place  0.06
# 2              Brewery  0.06
# 3   Italian Restaurant  0.06
# 4  American Restaurant  0.04
#
#
# -------Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park-------
#                 venue  freq
# 0  Light Rail Station  0.33
# 1         Coffee Shop  0.33
# 2        Liquor Store  0.17
# 3         Supermarket  0.17
# 4   Accessories Store  0.00
#
#
# -------The Annex, North Midtown, Yorkville-------
#                        venue  freq
# 0                       Café  0.13
# 1             Sandwich Place  0.13
# 2  Middle Eastern Restaurant  0.04
# 3               Liquor Store  0.04
# 4                Coffee Shop  0.04
#
#
# -------The Beaches-------
#                venue  freq
# 0       Neighborhood  0.17
# 1        Coffee Shop  0.17
# 2  Health Food Store  0.17
# 3                Pub  0.17
# 4   Asian Restaurant  0.17
#
#
# -------The Danforth  East-------
#                      venue  freq
# 0                     Park  0.33
# 1              Film Studio  0.33
# 2             Intersection  0.33
# 3        Accessories Store  0.00
# 4  New American Restaurant  0.00
#
#
# -------The Danforth West, Riverdale-------
#             venue  freq
# 0  Discount Store  0.12
# 1            Park  0.12
# 2  Ice Cream Shop  0.12
# 3    Intersection  0.12
# 4        Bus Line  0.12
#
#
# -------The Kingsway, Montgomery Road, Old Mill North-------
#                      venue  freq
# 0                   Lounge   0.5
# 1                     Park   0.5
# 2  New American Restaurant   0.0
# 3             Neighborhood   0.0
# 4              Music Venue   0.0
#
#
# -------Thorncliffe Park-------
#             venue  freq
# 0     Yoga Studio  0.09
# 1     Gas Station  0.09
# 2            Park  0.09
# 3     Coffee Shop  0.09
# 4  Sandwich Place  0.09
#
#
# -------Toronto Dominion Centre, Design Exchange-------
#          venue  freq
# 0  Coffee Shop  0.11
# 1        Hotel  0.08
# 2         Café  0.06
# 3   Restaurant  0.03
# 4  Salad Place  0.03
#
#
# -------University of Toronto, Harbord-------
#                  venue  freq
# 0                 Café  0.10
# 1          Coffee Shop  0.06
# 2               Bakery  0.06
# 3  Japanese Restaurant  0.04
# 4           Restaurant  0.04
#
#
# -------Victoria Village-------
#                      venue  freq
# 0                     Park  0.33
# 1        German Restaurant  0.33
# 2            Grocery Store  0.33
# 3                Nightclub  0.00
# 4  New American Restaurant  0.00
#
#
# -------West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale-------
#                 venue  freq
# 0         Pizza Place   0.4
# 1            Tea Room   0.2
# 2      Sandwich Place   0.2
# 3  Chinese Restaurant   0.2
# 4           Pet Store   0.0
#
#
# -------Westmount-------
#                        venue  freq
# 0                Pizza Place  0.33
# 1             Sandwich Place  0.17
# 2                Coffee Shop  0.17
# 3         Chinese Restaurant  0.17
# 4  Middle Eastern Restaurant  0.17
#
#
# -------Weston-------
#                  venue  freq
# 0    Convenience Store   0.2
# 1  Fried Chicken Joint   0.2
# 2             Pharmacy   0.2
# 3                Diner   0.2
# 4          Pizza Place   0.2
#
#
# -------Wexford, Maryvale-------
#                      venue  freq
# 0             Home Service   0.5
# 1              Auto Garage   0.5
# 2            Moving Target   0.0
# 3                Newsagent   0.0
# 4  New American Restaurant   0.0
#
#
# -------Willowdale South-------
#                   venue  freq
# 0         Shopping Mall  0.08
# 1  Fast Food Restaurant  0.08
# 2           Coffee Shop  0.08
# 3        Ice Cream Shop  0.04
# 4     Korean Restaurant  0.04
#
#
# -------Willowdale West-------
#            venue  freq
# 0    Pizza Place  0.17
# 1  Grocery Store  0.17
# 2     Baby Store  0.17
# 3    Coffee Shop  0.17
# 4    Supermarket  0.17
#
#
# -------Willowdale, Newtonbrook-------
#                        venue  freq
# 0  Middle Eastern Restaurant  0.18
# 1                Pizza Place  0.09
# 2          Korean Restaurant  0.09
# 3                       Café  0.09
# 4              Grocery Store  0.05
#
#
# -------Woburn-------
#                    venue  freq
# 0                   Park  0.25
# 1  Korean BBQ Restaurant  0.25
# 2            Coffee Shop  0.25
# 3       Business Service  0.25
# 4      Accessories Store  0.00
#
#
# -------Woodbine Heights-------
#                        venue  freq
# 0              Grocery Store  0.16
# 1                   Pharmacy  0.11
# 2                       Café  0.11
# 3                   Bus Line  0.11
# 4  Middle Eastern Restaurant  0.05
#
#
# -------York Mills West-------
#                venue  freq
# 0  Convenience Store  0.25
# 1               Park  0.25
# 2        Coffee Shop  0.25
# 3          Speakeasy  0.25
# 4           Pie Shop  0.00
#
#
# -------York Mills, Silver Hills-------
#                      venue  freq
# 0                     Park   1.0
# 1        Accessories Store   0.0
# 2  New American Restaurant   0.0
# 3             Neighborhood   0.0
# 4              Music Venue   0.0

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
neighbourhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighbourhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighbourhoods_venues_sorted.head()
# Out:
#                                      Neighbourhood  ... 10th Most Common Venue
# 0                                        Agincourt  ...  Vietnamese Restaurant
# 1                           Alderwood, Long Branch  ...    Dumpling Restaurant
# 2  Bathurst Manor, Wilson Heights, Downsview North  ...            Flower Shop
# 3                                  Bayview Village  ...     Falafel Restaurant
# 4                Bedford Park, Lawrence Manor East  ...                Butcher
#
# [5 rows x 11 columns]

# %%
# set number of clusters
k_num_clusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=k_num_clusters, random_state=0).fit(toronto_grouped_clustering)
kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
kmeans.labels_[0:100]
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#        2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 0, 2, 0, 0, 2,
#        0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 0, 2, 2, 2, 2,
#        2, 0, 2, 2, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 0, 2,
#        2, 2, 0, 2, 2, 2, 1, 2, 2, 2, 0, 2], dtype=int32)

# %%
neighbourhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
toronto_merged = df2

toronto_merged = toronto_merged.join(neighbourhoods_venues_sorted.set_index('Neighbourhood'), on='Neighborhood')

toronto_merged.head()
# Out:
#   PostalCode           Borough  ...     9th Most Common Venue  10th Most Common Venue
# 0        M3A        North York  ...               Event Space             Yoga Studio
# 1        M4A        North York  ...      Ethiopian Restaurant             Yoga Studio
# 2        M5A  Downtown Toronto  ...                    Bakery                     Pub
# 3        M6A        North York  ...             Smoothie Shop     Leather Goods Store
# 4        M7A      Queen's Park  ...  Mediterranean Restaurant           Burrito Place
#
# [5 rows x 16 columns]

# %%
toronto_merged_nonan = toronto_merged.dropna(subset=['Cluster Labels'])

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(k_num_clusters)
ys = [i + x + (i*x)**2 for i in range(k_num_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged_nonan['latitude'], toronto_merged_nonan['longitude'], toronto_merged_nonan['Neighborhood'], toronto_merged_nonan['Cluster Labels']):
    label = folium.Popup('Cluster ' + str(int(cluster) +1) + '\n' + str(poi) , parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster-1)]
        ).add_to(map_clusters)
        
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_ab64117f282b4744ae61e0086bf6013d%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ab64117f282b4744ae61e0086bf6013d%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_ab64117f282b4744ae61e0086bf6013d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_ab64117f282b4744ae61e0086bf6013d%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_7dcd0b4132cd4ea6a7213ad04e8c2871%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# cluster 1

# %%
toronto_merged_nonan.loc[toronto_merged_nonan['Cluster Labels'] == 0, toronto_merged_nonan.columns[[1] + list(range(5, toronto_merged_nonan.shape[1]))]]
# Out:
#                    Borough  ...  10th Most Common Venue
# 0               North York  ...             Yoga Studio
# 1               North York  ...             Yoga Studio
# 7               North York  ...             Event Space
# 18             Scarborough  ...             Escape Room
# 22             Scarborough  ...    Ethiopian Restaurant
# 27              North York  ...      Falafel Restaurant
# 35  East York/East Toronto  ...             Event Space
# 49              North York  ...             Yoga Studio
# 57              North York  ...      Falafel Restaurant
# 66              North York  ...                    Farm
# 69            West Toronto  ...      Falafel Restaurant
# 73         Central Toronto  ...             Event Space
# 88               Etobicoke  ...          Farmers Market
# 91        Downtown Toronto  ...    Ethiopian Restaurant
# 98               Etobicoke  ...             Yoga Studio
#
# [15 rows x 12 columns]

# %% [markdown]
# cluster 2

# %%
toronto_merged_nonan.loc[toronto_merged_nonan['Cluster Labels'] == 1, toronto_merged_nonan.columns[[1] + list(range(5, toronto_merged_nonan.shape[1]))]]
# Out:
#             Borough  ...  10th Most Common Venue
# 62  Central Toronto  ...          Farmers Market
# 71      Scarborough  ...                    Farm
#
# [2 rows x 12 columns]

# %% [markdown]
# cluster 3

# %%
toronto_merged_nonan.loc[toronto_merged_nonan['Cluster Labels'] == 2, toronto_merged_nonan.columns[[1] + list(range(5, toronto_merged_nonan.shape[1]))]]
# Out:
#                    Borough  ...    10th Most Common Venue
# 2         Downtown Toronto  ...                       Pub
# 3               North York  ...       Leather Goods Store
# 4             Queen's Park  ...             Burrito Place
# 5                Etobicoke  ...         Electronics Store
# 6              Scarborough  ...        Falafel Restaurant
# ..                     ...  ...                       ...
# 97        Downtown Toronto  ...       American Restaurant
# 99        Downtown Toronto  ...  Mediterranean Restaurant
# 100  East Toronto Business  ...        Italian Restaurant
# 101              Etobicoke  ...                      Farm
# 102              Etobicoke  ...                       Gym
#
# [82 rows x 12 columns]

# %% [markdown]
# cluster 4

# %%
toronto_merged_nonan.loc[toronto_merged_nonan['Cluster Labels'] == 3, toronto_merged_nonan.columns[[1] + list(range(5, toronto_merged_nonan.shape[1]))]]
# Out:
#             Borough  ...  10th Most Common Venue
# 45       North York  ...             Dry Cleaner
# 68  Central Toronto  ...             Dry Cleaner
#
# [2 rows x 12 columns]

# %% [markdown]
# cluster 5

# %%
toronto_merged_nonan.loc[toronto_merged_nonan['Cluster Labels'] == 4, toronto_merged_nonan.columns[[1] + list(range(5, toronto_merged_nonan.shape[1]))]]
# Out:
#        Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 53  North York             4.0  ...           Yoga Studio    Dumpling Restaurant
#
# [1 rows x 12 columns]
